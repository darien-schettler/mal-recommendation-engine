# %%
import pickle

# %%
user_dict = pickle.load( open( "big_user_dict_newest.pkl", "rb" ) )

# %%
for i, (key,value) in enumerate(user_dict.items()):
    if i > len(user_dict)-3:
        print("\nUSER: {}\n".format(key))
        for k, v in value.items():
            print("TITLE : {}\nSCORE : {}\n".format(k,v))
# Out:
# USER: Sin_the_Demon
#
# TITLE : Akame ga Kill!
# SCORE : 0
#
# TITLE : 91 Days
# SCORE : 8
#
# TITLE : Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.
# SCORE : 10
#
# TITLE : Another
# SCORE : 5
#
# TITLE : Ao no Exorcist
# SCORE : 7
#
# TITLE : Beck
# SCORE : 9
#
# TITLE : Black Lagoon
# SCORE : 10
#
# TITLE : Bleach
# SCORE : 6
#
# TITLE : Boku no Pico
# SCORE : 1
#
# TITLE : Citrus
# SCORE : 6
#
# TITLE : Corpse Party: Missing Footage
# SCORE : 5
#
# TITLE : Corpse Party: Tortured Souls - Bougyakusareta Tamashii no Jukyou
# SCORE : 4
#
# TITLE : Deadman Wonderland
# SCORE : 6
#
# TITLE : Deadman Wonderland: Akai Knife Tsukai
# SCORE : 6
#
# TITLE : Elfen Lied
# SCORE : 8
#
# TITLE : Fate/kaleid liner Prisma☆Illya
# SCORE : 2
#
# TITLE : Fukumenkei Noise
# SCORE : 9
#
# TITLE : Fullmetal Alchemist: Brotherhood
# SCORE : 8
#
# TITLE : Futa-bu!
# SCORE : 5
#
# TITLE : Gamers!
# SCORE : 4
#
# TITLE : Gangsta.
# SCORE : 7
#
# TITLE : Girls Bravo: First Season
# SCORE : 6
#
# ...
